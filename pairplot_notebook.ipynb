# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

Df=pd.read_csv("MarketingExpenses_SalesRevenue.csv")
#Df
sns.pairplot(Df, vars=['Socialmedia_ads'],hue='Sales_revenue')
plt.show()
